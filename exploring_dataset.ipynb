# %%
import pandas as pd

# %%
MCU = '/home/theaiunicorn/Downloads/MCU_timeline.csv'

# %%
df = pd.read_csv(MCU)

# %%
df.head()
# Out:
#                                   name       year  duration(min)  \
# 0  Captain America: The First Avenger   1942-1945          124.0
# 1                Agent Carter season 1       1946          360.0
# 2                Agent Carter season 2       1947          450.0
# 3                       Captain Marvel       1995          124.0
# 4                             Iron Man       2010          126.0
#
#    number_episodes        watch    type
# 0              1.0  disney plus   movie
# 1              8.0  disney plus  series
# 2             10.0  disney plus  series
# 3              1.0  disney plus   movie
# 4              1.0  disney plus   movie

# %%
# shows only on netflix.
df_dp = df[df.watch == 'disney plus']

# %%
df_dp
# Out:
#                                                 name       year  \
# 0                Captain America: The First Avenger   1942-1945
# 1                              Agent Carter season 1       1946
# 2                              Agent Carter season 2       1947
# 3                                     Captain Marvel       1995
# 4                                           Iron Man       2010
# 5                                         Iron Man 2       2011
# 7                                               Thor       2011
# 8                                           Avengers       2012
# 9            Agents of Shield season 1, episodes 1-7       2013
# 10                              Thor: The Dark World       2013
# 11                                        Iron Man 3       2012
# 12          Agents of Shield season 1, episodes 8-16  2013-2014
# 13               Captain America: The Winter Soldier       2014
# 14         Agents of Shield season 1, episodes 17-22       2014
# ...

# %%
# shows only on netflix.
df_n = df[df.watch == 'netflix']

# %%
df_n
# Out:
#                             name  year  duration(min)  number_episodes  \
# 15            Daredevil season 1  2014          780.0             13.0
# 22        Jessica Jones season 1  2015          715.0             13.0
# 23            Daredevil season 2  2015          650.0             13.0
# 24            Luke Cage season 1  2015          717.0             13.0
# 30     Iron Fist season 1 (2016)  2016          780.0             13.0
# 31          The Defenders (2016)  2016          440.0              8.0
# 33  The Punisher season 1 (2016)  2016          715.0             13.0
# 37        Jessica Jones season 2  2017          650.0             13.0
# 39            Luke Cage season 2  2017          715.0             13.0
# 40            Iron Fist season 2  2017          550.0             10.0
# 41            Daredevil season 3  2017          550.0             10.0
# 42         The Punisher season 2  2017          715.0             13.0
# ...

# %%
git remote add origin git@github.com:theaigirl/bing_watching.git
git branch -M main
git push -u origin main
